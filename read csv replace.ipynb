# %%
import pandas as pd
k=pd.read_csv('F:\\suryakant notes\\pra1.csv')
k
# Out:
#    ID       Name    Companies      Profit Growth
# 0    1   Lamtone  IT services   5274553.0    30%
# 1    2  Strifind      Finance         NaN    20%
# 2    3       NaN       Health  47689453.0     7%
# 3    4       NaN  IT services  23562549.0    NaN
# 4    5      Mark   Insurances   4563782.0    26%

# %%
k.replace(to_replace='IT services',value='IIT')
# Out:
#    ID       Name   Companies      Profit Growth
# 0    1   Lamtone         IIT   5274553.0    30%
# 1    2  Strifind     Finance         NaN    20%
# 2    3       NaN      Health  47689453.0     7%
# 3    4       NaN         IIT  23562549.0    NaN
# 4    5      Mark  Insurances   4563782.0    26%

# %%
k.replace(2,30)
# Out:
#    ID       Name    Companies      Profit Growth
# 0    1   Lamtone  IT services   5274553.0    30%
# 1   30  Strifind      Finance         NaN    20%
# 2    3       NaN       Health  47689453.0     7%
# 3    4       NaN  IT services  23562549.0    NaN
# 4    5      Mark   Insurances   4563782.0    26%

# %%
k.replace({'Companies':'[A-Za-z]'},101,regex=True)
# Out:
#    ID       Name  Companies      Profit Growth
# 0    1   Lamtone        101   5274553.0    30%
# 1    2  Strifind        101         NaN    20%
# 2    3       NaN        101  47689453.0     7%
# 3    4       NaN        101  23562549.0    NaN
# 4    5      Mark        101   4563782.0    26%

# %%
k
# Out:
#    ID       Name    Companies      Profit Growth
# 0    1   Lamtone  IT services   5274553.0    30%
# 1    2  Strifind      Finance         NaN    20%
# 2    3       NaN       Health  47689453.0     7%
# 3    4       NaN  IT services  23562549.0    NaN
# 4    5      Mark   Insurances   4563782.0    26%

# %%
k.replace('Health',method='ffill')
# Out:
#    ID       Name    Companies      Profit Growth
# 0    1   Lamtone  IT services   5274553.0    30%
# 1    2  Strifind      Finance         NaN    20%
# 2    3       NaN      Finance  47689453.0     7%
# 3    4       NaN  IT services  23562549.0    NaN
# 4    5      Mark   Insurances   4563782.0    26%

# %%
k.replace('IT services',method='bfill',limit=2)
# Out:
#    ID       Name   Companies      Profit Growth
# 0    1   Lamtone     Finance   5274553.0    30%
# 1    2  Strifind     Finance         NaN    20%
# 2    3       NaN      Health  47689453.0     7%
# 3    4       NaN  Insurances  23562549.0    NaN
# 4    5      Mark  Insurances   4563782.0    26%

# %%
k.replace('Health','Innnn',inplace=False)
# Out:
#    ID       Name    Companies      Profit Growth
# 0    1   Lamtone  IT services   5274553.0    30%
# 1    2  Strifind      Finance         NaN    20%
# 2    3       NaN        Innnn  47689453.0     7%
# 3    4       NaN  IT services  23562549.0    NaN
# 4    5      Mark   Insurances   4563782.0    26%

# %%
k
# Out:
#    ID       Name    Companies      Profit Growth
# 0    1   Lamtone  IT services   5274553.0    30%
# 1    2  Strifind      Finance         NaN    20%
# 2    3       NaN        Innnn  47689453.0     7%
# 3    4       NaN  IT services  23562549.0    NaN
# 4    5      Mark   Insurances   4563782.0    26%

# %%
k.interpolate(method='index')
# Out:
#    ID       Name    Companies      Profit Growth
# 0    1   Lamtone  IT services   5274553.0    30%
# 1    2  Strifind      Finance  26482003.0    20%
# 2    3       NaN        Innnn  47689453.0     7%
# 3    4       NaN  IT services  23562549.0    NaN
# 4    5      Mark   Insurances   4563782.0    26%

# %%
k.interpolate()
# Out:
#    ID       Name    Companies      Profit Growth
# 0    1   Lamtone  IT services   5274553.0    30%
# 1    2  Strifind      Finance  26482003.0    20%
# 2    3       NaN        Innnn  47689453.0     7%
# 3    4       NaN  IT services  23562549.0    NaN
# 4    5      Mark   Insurances   4563782.0    26%

# %%
k.interpolate(method='polynomial',order=2)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7180/2538445732.py in <module>
# ----> 1 k.interpolate(method='polynomial',order=2)
#
# c:\users\jambhale\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    7215                 "those NaNs before interpolating."
#    7216             )
# -> 7217         new_data = obj._mgr.interpolate(
#    7218             method=method,
#    7219             axis=axis,
#
# c:\users\jambhale\appdata\local\programs\python\python38\lib\site-packages\pandas\core\internals\managers.py in interpolate(self, **kwargs)
#     591
#     592     def interpolate(self, **kwargs) -> "BlockManager":
# --> 593         return self.apply("interpolate", **kwargs)
#     594
# ...

# %%
k.interpolate(axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7180/1103790372.py in <module>
# ----> 1 k.interpolate(axis=1)
#
# c:\users\jambhale\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    7182
#    7183         if obj.ndim == 2 and np.all(obj.dtypes == np.dtype(object)):
# -> 7184             raise TypeError(
#    7185                 "Cannot interpolate with all object-dtype columns "
#    7186                 "in the DataFrame. Try setting at least one "
#
# TypeError: Cannot interpolate with all object-dtype columns in the DataFrame. Try setting at least one column to a numeric dtype.

# %%
k.interpolate(limit=1)
# Out:
#    ID       Name    Companies      Profit Growth
# 0    1   Lamtone  IT services   5274553.0    30%
# 1    2  Strifind      Finance  26482003.0    20%
# 2    3       NaN        Innnn  47689453.0     7%
# 3    4       NaN  IT services  23562549.0    NaN
# 4    5      Mark   Insurances   4563782.0    26%

# %%
k.interpolate(limit=1,limit_direction='backward')
# Out:
#    ID       Name    Companies      Profit Growth
# 0    1   Lamtone  IT services   5274553.0    30%
# 1    2  Strifind      Finance  26482003.0    20%
# 2    3       NaN        Innnn  47689453.0     7%
# 3    4       NaN  IT services  23562549.0    NaN
# 4    5      Mark   Insurances   4563782.0    26%
