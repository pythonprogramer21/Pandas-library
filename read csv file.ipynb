# %%
import pandas as pd
k=pd.read_csv('F:\\suryakant notes\\practis.csv',usecols=['Username','Password'])
k
# Out:
#                                 Username  Password
# 0           aakif.khan@abmspcoerpune.org  Fot79292
# 1       amarsinh.tarte@abmspcoerpune.org  Kut58666
# 2       vikram.bhosale@abmspcoerpune.org  Zag01909
# 3   vaishnavi.boravake@abmspcoerpune.org  Zat69168
# 4      rahul.chalavade@abmspcoerpune.org  Vut07294
# ..                                   ...       ...
# 76   sushant.kawalekar@abmspcoerpune.org  Mas73644
# 77      rutweek.todkar@abmspcoerpune.org  Muc94045
# 78       jayshri.totre@abmspcoerpune.org  Dog05275
# 79  yadnesh.haribhakta@abmspcoerpune.org  Sad29461
# 80        akash.zagade@abmspcoerpune.org  Wuh25383
#
# [81 rows x 2 columns]

# %%
type(k)
# Out:
# pandas.core.frame.DataFrame

# %%
k.columns
# Out:
# Index(['Display name', 'Username', 'Password', 'Licenses'], dtype='object')

# %%
k1=pd.read_csv('F:\\suryakant notes\\practis.csv',skiprows=1)
k1
# Out:
#           Display name                              Username  Password  \
# 0           Aakif Khan          aakif.khan@abmspcoerpune.org  Fot79292
# 1       Amarsinh Tarte      amarsinh.tarte@abmspcoerpune.org  Kut58666
# 2       Vikram Bhosale      vikram.bhosale@abmspcoerpune.org  Zag01909
# 3   Vaishnavi Boravake  vaishnavi.boravake@abmspcoerpune.org  Zat69168
# 4      Rahul Chalavade     rahul.chalavade@abmspcoerpune.org  Vut07294
# ..                 ...                                   ...       ...
# 76   Sushant Kawalekar   sushant.kawalekar@abmspcoerpune.org  Mas73644
# 77      Rutweek Todkar      rutweek.todkar@abmspcoerpune.org  Muc94045
# 78       Jayshri Totre       jayshri.totre@abmspcoerpune.org  Dog05275
# 79  Yadnesh Haribhakta  yadnesh.haribhakta@abmspcoerpune.org  Sad29461
# 80        Akash Zagade        akash.zagade@abmspcoerpune.org  Wuh25383
#
#                                      Licenses
# 0   Microsoft 365 A3 for students use benefit
# ...

# %%
k2=pd.read_csv('F:\\suryakant notes\\practis.csv',index_col='Password')
k2
# Out:
#                 Display name                              Username  \
# Password
# Fot79292          Aakif Khan          aakif.khan@abmspcoerpune.org
# Kut58666      Amarsinh Tarte      amarsinh.tarte@abmspcoerpune.org
# Zag01909      Vikram Bhosale      vikram.bhosale@abmspcoerpune.org
# Zat69168  Vaishnavi Boravake  vaishnavi.boravake@abmspcoerpune.org
# Vut07294     Rahul Chalavade     rahul.chalavade@abmspcoerpune.org
# ...                      ...                                   ...
# Mas73644   Sushant Kawalekar   sushant.kawalekar@abmspcoerpune.org
# Muc94045      Rutweek Todkar      rutweek.todkar@abmspcoerpune.org
# Dog05275       Jayshri Totre       jayshri.totre@abmspcoerpune.org
# Sad29461  Yadnesh Haribhakta  yadnesh.haribhakta@abmspcoerpune.org
# Wuh25383        Akash Zagade        akash.zagade@abmspcoerpune.org
#
#                                            Licenses
# Password
# Fot79292  Microsoft 365 A3 for students use benefit
# ...

# %%
k3=pd.read_csv('F:\\suryakant notes\\practis.csv',header=3)
k3
# Out:
#         Amarsinh Tarte      amarsinh.tarte@abmspcoerpune.org  Kut58666  \
# 0       Vikram Bhosale      vikram.bhosale@abmspcoerpune.org  Zag01909
# 1   Vaishnavi Boravake  vaishnavi.boravake@abmspcoerpune.org  Zat69168
# 2      Rahul Chalavade     rahul.chalavade@abmspcoerpune.org  Vut07294
# 3         Tejas Chavan        tejas.chavan@abmspcoerpune.org  Qaw22607
# 4          Rahul Dalvi         rahul.dalvi@abmspcoerpune.org  Yat76616
# ..                 ...                                   ...       ...
# 74   Sushant Kawalekar   sushant.kawalekar@abmspcoerpune.org  Mas73644
# 75      Rutweek Todkar      rutweek.todkar@abmspcoerpune.org  Muc94045
# 76       Jayshri Totre       jayshri.totre@abmspcoerpune.org  Dog05275
# 77  Yadnesh Haribhakta  yadnesh.haribhakta@abmspcoerpune.org  Sad29461
# 78        Akash Zagade        akash.zagade@abmspcoerpune.org  Wuh25383
#
#     Microsoft 365 A3 for students use benefit
# 0   Microsoft 365 A3 for students use benefit
# ...

# %%
k4=pd.read_csv('F:\\suryakant notes\\practis.csv',names=['Display name', 'Username', 'Password', 'Licenses'])
k4
# Out:
#           Display name                              Username  Password  \
# 0           Aakif Khan          aakif.khan@abmspcoerpune.org  Fot79292
# 1       Amarsinh Tarte      amarsinh.tarte@abmspcoerpune.org  Kut58666
# 2       Vikram Bhosale      vikram.bhosale@abmspcoerpune.org  Zag01909
# 3   Vaishnavi Boravake  vaishnavi.boravake@abmspcoerpune.org  Zat69168
# 4      Rahul Chalavade     rahul.chalavade@abmspcoerpune.org  Vut07294
# ..                 ...                                   ...       ...
# 76   Sushant Kawalekar   sushant.kawalekar@abmspcoerpune.org  Mas73644
# 77      Rutweek Todkar      rutweek.todkar@abmspcoerpune.org  Muc94045
# 78       Jayshri Totre       jayshri.totre@abmspcoerpune.org  Dog05275
# 79  Yadnesh Haribhakta  yadnesh.haribhakta@abmspcoerpune.org  Sad29461
# 80        Akash Zagade        akash.zagade@abmspcoerpune.org  Wuh25383
#
#                                      Licenses
# 0   Microsoft 365 A3 for students use benefit
# ...

# %%
k4.head(20)
# Out:
#           Display name                              Username  Password  \
# 0           Aakif Khan          aakif.khan@abmspcoerpune.org  Fot79292
# 1       Amarsinh Tarte      amarsinh.tarte@abmspcoerpune.org  Kut58666
# 2       Vikram Bhosale      vikram.bhosale@abmspcoerpune.org  Zag01909
# 3   Vaishnavi Boravake  vaishnavi.boravake@abmspcoerpune.org  Zat69168
# 4      Rahul Chalavade     rahul.chalavade@abmspcoerpune.org  Vut07294
# 5         Tejas Chavan        tejas.chavan@abmspcoerpune.org  Qaw22607
# 6          Rahul Dalvi         rahul.dalvi@abmspcoerpune.org  Yat76616
# 7   Sudarshan Deshmukh  sudarshan.deshmukh@abmspcoerpune.org  Hoc26297
# 8      Prajakta Dhanve     prajakta.dhanve@abmspcoerpune.org  Kot18902
# 9         Sakshi Dhole        sakshi.dhole@abmspcoerpune.org  Gof31562
# 10      Abhishek Dighe      abhishek.dighe@abmspcoerpune.org  Caw06258
# 11         Sagar Donge         sagar.donge@abmspcoerpune.org  Vuc88654
# ...

# %%
k4.tail(10)
# Out:
#           Display name                              Username  Password  \
# 71    Suvarna Sontakke    suvarna.sontakke@abmspcoerpune.org  Ruw48907
# 72     Akshata Sonwane     akshata.sonwane@abmspcoerpune.org  Quh92415
# 73       Jidnyasa Suki       jidnyasa.suki@abmspcoerpune.org  Koy86273
# 74      Sharwari Surve      sharwari.surve@abmspcoerpune.org  Cuw94622
# 75  Suryakant Jambhale  suryakant.jambhale@abmspcoerpune.org  Cuh22493
# 76   Sushant Kawalekar   sushant.kawalekar@abmspcoerpune.org  Mas73644
# 77      Rutweek Todkar      rutweek.todkar@abmspcoerpune.org  Muc94045
# 78       Jayshri Totre       jayshri.totre@abmspcoerpune.org  Dog05275
# 79  Yadnesh Haribhakta  yadnesh.haribhakta@abmspcoerpune.org  Sad29461
# 80        Akash Zagade        akash.zagade@abmspcoerpune.org  Wuh25383
#
#                                      Licenses
# 71  Microsoft 365 A3 for students use benefit
# 72  Microsoft 365 A3 for students use benefit
# 73  Microsoft 365 A3 for students use benefit
# ...

# %%
k5=pd.read_csv('F:\\suryakant notes\\practis.csv',dtype={'ID':'float64'})
k5
# Out:
#       ID        Display name                              Username  Password  \
# 0    1.0          Aakif Khan          aakif.khan@abmspcoerpune.org  Fot79292
# 1    2.0      Amarsinh Tarte      amarsinh.tarte@abmspcoerpune.org  Kut58666
# 2    3.0      Vikram Bhosale      vikram.bhosale@abmspcoerpune.org  Zag01909
# 3    4.0  Vaishnavi Boravake  vaishnavi.boravake@abmspcoerpune.org  Zat69168
# 4    5.0     Rahul Chalavade     rahul.chalavade@abmspcoerpune.org  Vut07294
# ..   ...                 ...                                   ...       ...
# 76  77.0   Sushant Kawalekar   sushant.kawalekar@abmspcoerpune.org  Mas73644
# 77  78.0      Rutweek Todkar      rutweek.todkar@abmspcoerpune.org  Muc94045
# 78  79.0       Jayshri Totre       jayshri.totre@abmspcoerpune.org  Dog05275
# 79  80.0  Yadnesh Haribhakta  yadnesh.haribhakta@abmspcoerpune.org  Sad29461
# 80  81.0        Akash Zagade        akash.zagade@abmspcoerpune.org  Wuh25383
#
# ...

# %%
k6=pd.read_csv('F:\\suryakant notes\\practis.csv',na_values='not data')
k6
# Out:
#      ID        Display name                              Username  Password  \
# 0     1          Aakif Khan          aakif.khan@abmspcoerpune.org  Fot79292
# 1     2      Amarsinh Tarte      amarsinh.tarte@abmspcoerpune.org  Kut58666
# 2   NaN      Vikram Bhosale      vikram.bhosale@abmspcoerpune.org  Zag01909
# 3     4  Vaishnavi Boravake  vaishnavi.boravake@abmspcoerpune.org  Zat69168
# 4     5     Rahul Chalavade     rahul.chalavade@abmspcoerpune.org  Vut07294
# ..  ...                 ...                                   ...       ...
# 76   77   Sushant Kawalekar   sushant.kawalekar@abmspcoerpune.org  Mas73644
# 77   78      Rutweek Todkar      rutweek.todkar@abmspcoerpune.org  Muc94045
# 78   79       Jayshri Totre       jayshri.totre@abmspcoerpune.org  Dog05275
# 79   80  Yadnesh Haribhakta  yadnesh.haribhakta@abmspcoerpune.org  Sad29461
# 80   81        Akash Zagade        akash.zagade@abmspcoerpune.org  Wuh25383
#
#                                      Licenses
# ...

# %%
k7=pd.read_csv('F:\\suryakant notes\\practis.csv',keep_default_na=False)
k7
# Out:
#           ID        Display name                              Username  \
# 0          1          Aakif Khan          aakif.khan@abmspcoerpune.org
# 1          2      Amarsinh Tarte      amarsinh.tarte@abmspcoerpune.org
# 2   not data      Vikram Bhosale      vikram.bhosale@abmspcoerpune.org
# 3          4  Vaishnavi Boravake  vaishnavi.boravake@abmspcoerpune.org
# 4          5     Rahul Chalavade     rahul.chalavade@abmspcoerpune.org
# ..       ...                 ...                                   ...
# 76             Sushant Kawalekar   sushant.kawalekar@abmspcoerpune.org
# 77        78      Rutweek Todkar      rutweek.todkar@abmspcoerpune.org
# 78        79       Jayshri Totre       jayshri.totre@abmspcoerpune.org
# 79            Yadnesh Haribhakta  yadnesh.haribhakta@abmspcoerpune.org
# 80        81        Akash Zagade        akash.zagade@abmspcoerpune.org
#
#     Password                                   Licenses
# 0   Fot79292  Microsoft 365 A3 for students use benefit
# ...

# %%
k8=pd.read_csv('F:\\suryakant notes\\practis.csv',keep_default_na=True)
k8
# Out:
#           ID        Display name                              Username  \
# 0          1          Aakif Khan          aakif.khan@abmspcoerpune.org
# 1          2      Amarsinh Tarte      amarsinh.tarte@abmspcoerpune.org
# 2   not data      Vikram Bhosale      vikram.bhosale@abmspcoerpune.org
# 3          4  Vaishnavi Boravake  vaishnavi.boravake@abmspcoerpune.org
# 4          5     Rahul Chalavade     rahul.chalavade@abmspcoerpune.org
# ..       ...                 ...                                   ...
# 76       NaN   Sushant Kawalekar   sushant.kawalekar@abmspcoerpune.org
# 77        78      Rutweek Todkar      rutweek.todkar@abmspcoerpune.org
# 78        79       Jayshri Totre       jayshri.totre@abmspcoerpune.org
# 79       NaN  Yadnesh Haribhakta  yadnesh.haribhakta@abmspcoerpune.org
# 80        81        Akash Zagade        akash.zagade@abmspcoerpune.org
#
#     Password                                   Licenses
# 0   Fot79292  Microsoft 365 A3 for students use benefit
# ...

# %%
k9=pd.read_csv('F:\\suryakant notes\\practis.csv',na_filter=False)
k9
# Out:
#           ID        Display name                              Username  \
# 0          1          Aakif Khan          aakif.khan@abmspcoerpune.org
# 1          2      Amarsinh Tarte      amarsinh.tarte@abmspcoerpune.org
# 2   not data      Vikram Bhosale      vikram.bhosale@abmspcoerpune.org
# 3          4  Vaishnavi Boravake  vaishnavi.boravake@abmspcoerpune.org
# 4          5     Rahul Chalavade     rahul.chalavade@abmspcoerpune.org
# ..       ...                 ...                                   ...
# 76             Sushant Kawalekar   sushant.kawalekar@abmspcoerpune.org
# 77        78      Rutweek Todkar      rutweek.todkar@abmspcoerpune.org
# 78        79       Jayshri Totre       jayshri.totre@abmspcoerpune.org
# 79            Yadnesh Haribhakta  yadnesh.haribhakta@abmspcoerpune.org
# 80        81        Akash Zagade        akash.zagade@abmspcoerpune.org
#
#     Password                                   Licenses
# 0   Fot79292  Microsoft 365 A3 for students use benefit
# ...

# %%
k9.isnull()
# Out:
#        ID  Display name  Username  Password  Licenses
# 0   False         False     False     False     False
# 1   False         False     False     False     False
# 2   False         False     False     False     False
# 3   False         False     False     False     False
# 4   False         False     False     False     False
# ..    ...           ...       ...       ...       ...
# 76  False         False     False     False     False
# 77  False         False     False     False     False
# 78  False         False     False     False     False
# 79  False         False     False     False     False
# 80  False         False     False     False     False
#
# [81 rows x 5 columns]

# %%
k10=pd.read_csv('F:\\suryakant notes\\practis.csv')
k10
# Out:
#           ID        Display name                              Username  \
# 0          1          Aakif Khan          aakif.khan@abmspcoerpune.org
# 1          2      Amarsinh Tarte      amarsinh.tarte@abmspcoerpune.org
# 2   not data      Vikram Bhosale      vikram.bhosale@abmspcoerpune.org
# 3          4  Vaishnavi Boravake  vaishnavi.boravake@abmspcoerpune.org
# 4          5     Rahul Chalavade     rahul.chalavade@abmspcoerpune.org
# ..       ...                 ...                                   ...
# 76       NaN   Sushant Kawalekar   sushant.kawalekar@abmspcoerpune.org
# 77        78      Rutweek Todkar      rutweek.todkar@abmspcoerpune.org
# 78        79       Jayshri Totre       jayshri.totre@abmspcoerpune.org
# 79       NaN  Yadnesh Haribhakta  yadnesh.haribhakta@abmspcoerpune.org
# 80        81        Akash Zagade        akash.zagade@abmspcoerpune.org
#
#     Password                                   Licenses
# 0   Fot79292  Microsoft 365 A3 for students use benefit
# ...

# %%
k10.isnull()
# Out:
#        ID  Display name  Username  Password  Licenses
# 0   False         False     False     False     False
# 1   False         False     False     False     False
# 2   False         False     False     False     False
# 3   False         False     False     False     False
# 4   False         False     False     False     False
# ..    ...           ...       ...       ...       ...
# 76   True         False     False     False     False
# 77  False         False     False     False     False
# 78  False         False     False     False     False
# 79   True         False     False     False     False
# 80  False         False     False     False     False
#
# [81 rows x 5 columns]

# %%
k10.isnull().sum()
# Out:
# ID              2
# Display name    0
# Username        0
# Password        0
# Licenses        0
# dtype: int64

# %%
k10.isnull().sum().sum()
# Out:
# 2

# %%
k10.notnull()
# Out:
#        ID  Display name  Username  Password  Licenses
# 0    True          True      True      True      True
# 1    True          True      True      True      True
# 2    True          True      True      True      True
# 3    True          True      True      True      True
# 4    True          True      True      True      True
# ..    ...           ...       ...       ...       ...
# 76  False          True      True      True      True
# 77   True          True      True      True      True
# 78   True          True      True      True      True
# 79  False          True      True      True      True
# 80   True          True      True      True      True
#
# [81 rows x 5 columns]

# %%
k10.notnull().sum()
# Out:
# ID              79
# Display name    81
# Username        81
# Password        81
# Licenses        81
# dtype: int64

# %%
k10.notnull().sum().sum()
# Out:
# 403

# %%
k10.dropna()
# Out:
#           ID        Display name                              Username  \
# 0          1          Aakif Khan          aakif.khan@abmspcoerpune.org
# 1          2      Amarsinh Tarte      amarsinh.tarte@abmspcoerpune.org
# 2   not data      Vikram Bhosale      vikram.bhosale@abmspcoerpune.org
# 3          4  Vaishnavi Boravake  vaishnavi.boravake@abmspcoerpune.org
# 4          5     Rahul Chalavade     rahul.chalavade@abmspcoerpune.org
# ..       ...                 ...                                   ...
# 74        75      Sharwari Surve      sharwari.surve@abmspcoerpune.org
# 75        76  Suryakant Jambhale  suryakant.jambhale@abmspcoerpune.org
# 77        78      Rutweek Todkar      rutweek.todkar@abmspcoerpune.org
# 78        79       Jayshri Totre       jayshri.totre@abmspcoerpune.org
# 80        81        Akash Zagade        akash.zagade@abmspcoerpune.org
#
#     Password                                   Licenses
# 0   Fot79292  Microsoft 365 A3 for students use benefit
# ...

# %%
k10.dropna(axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9568/4220048159.py in <module>
# ----> 1 k10.dropna(axis=1)
#
# NameError: name 'k10' is not defined

# %%
k11=pd.read_csv('F:\\suryakant notes\\practis.csv')
k11.dropna(axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9568/4213635927.py in <module>
# ----> 1 k11=pd.read_csv('F:\\suryakant notes\\practis.csv')
#       2 k11.dropna(axis=1)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
k12=pd.read_csv('F:\\suryakant notes\\practis.csv')
k12
# Out:
#           ID        Display name                              Username  \
# 0          1          Aakif Khan          aakif.khan@abmspcoerpune.org
# 1          2      Amarsinh Tarte      amarsinh.tarte@abmspcoerpune.org
# 2   not data      Vikram Bhosale      vikram.bhosale@abmspcoerpune.org
# 3          4  Vaishnavi Boravake  vaishnavi.boravake@abmspcoerpune.org
# 4          5     Rahul Chalavade     rahul.chalavade@abmspcoerpune.org
# ..       ...                 ...                                   ...
# 76       NaN   Sushant Kawalekar   sushant.kawalekar@abmspcoerpune.org
# 77        78      Rutweek Todkar      rutweek.todkar@abmspcoerpune.org
# 78        79       Jayshri Totre       jayshri.totre@abmspcoerpune.org
# 79       NaN  Yadnesh Haribhakta  yadnesh.haribhakta@abmspcoerpune.org
# 80        81        Akash Zagade        akash.zagade@abmspcoerpune.org
#
#     Password                                   Licenses
# 0   Fot79292  Microsoft 365 A3 for students use benefit
# ...

# %%
k12.dropna(axis=1)
# Out:
#           Display name                              Username  Password  \
# 0           Aakif Khan          aakif.khan@abmspcoerpune.org  Fot79292
# 1       Amarsinh Tarte      amarsinh.tarte@abmspcoerpune.org  Kut58666
# 2       Vikram Bhosale      vikram.bhosale@abmspcoerpune.org  Zag01909
# 3   Vaishnavi Boravake  vaishnavi.boravake@abmspcoerpune.org  Zat69168
# 4      Rahul Chalavade     rahul.chalavade@abmspcoerpune.org  Vut07294
# ..                 ...                                   ...       ...
# 76   Sushant Kawalekar   sushant.kawalekar@abmspcoerpune.org  Mas73644
# 77      Rutweek Todkar      rutweek.todkar@abmspcoerpune.org  Muc94045
# 78       Jayshri Totre       jayshri.totre@abmspcoerpune.org  Dog05275
# 79  Yadnesh Haribhakta  yadnesh.haribhakta@abmspcoerpune.org  Sad29461
# 80        Akash Zagade        akash.zagade@abmspcoerpune.org  Wuh25383
#
#                                      Licenses
# 0   Microsoft 365 A3 for students use benefit
# ...

# %%
k12.dropna(how='any')
# Out:
#           ID        Display name                              Username  \
# 0          1          Aakif Khan          aakif.khan@abmspcoerpune.org
# 1          2      Amarsinh Tarte      amarsinh.tarte@abmspcoerpune.org
# 2   not data      Vikram Bhosale      vikram.bhosale@abmspcoerpune.org
# 3          4  Vaishnavi Boravake  vaishnavi.boravake@abmspcoerpune.org
# 4          5     Rahul Chalavade     rahul.chalavade@abmspcoerpune.org
# ..       ...                 ...                                   ...
# 74        75      Sharwari Surve      sharwari.surve@abmspcoerpune.org
# 75        76  Suryakant Jambhale  suryakant.jambhale@abmspcoerpune.org
# 77        78      Rutweek Todkar      rutweek.todkar@abmspcoerpune.org
# 78        79       Jayshri Totre       jayshri.totre@abmspcoerpune.org
# 80        81        Akash Zagade        akash.zagade@abmspcoerpune.org
#
#     Password                                   Licenses
# 0   Fot79292  Microsoft 365 A3 for students use benefit
# ...

# %%
k12.dropna(axis=1,how='any')
# Out:
#           Display name                              Username  Password  \
# 0           Aakif Khan          aakif.khan@abmspcoerpune.org  Fot79292
# 1       Amarsinh Tarte      amarsinh.tarte@abmspcoerpune.org  Kut58666
# 2       Vikram Bhosale      vikram.bhosale@abmspcoerpune.org  Zag01909
# 3   Vaishnavi Boravake  vaishnavi.boravake@abmspcoerpune.org  Zat69168
# 4      Rahul Chalavade     rahul.chalavade@abmspcoerpune.org  Vut07294
# ..                 ...                                   ...       ...
# 76   Sushant Kawalekar   sushant.kawalekar@abmspcoerpune.org  Mas73644
# 77      Rutweek Todkar      rutweek.todkar@abmspcoerpune.org  Muc94045
# 78       Jayshri Totre       jayshri.totre@abmspcoerpune.org  Dog05275
# 79  Yadnesh Haribhakta  yadnesh.haribhakta@abmspcoerpune.org  Sad29461
# 80        Akash Zagade        akash.zagade@abmspcoerpune.org  Wuh25383
#
#                                      Licenses
# 0   Microsoft 365 A3 for students use benefit
# ...

# %%
k12.dropna(subset=['ID'])
# Out:
#           ID        Display name                              Username  \
# 0          1          Aakif Khan          aakif.khan@abmspcoerpune.org
# 1          2      Amarsinh Tarte      amarsinh.tarte@abmspcoerpune.org
# 2   not data      Vikram Bhosale      vikram.bhosale@abmspcoerpune.org
# 3          4  Vaishnavi Boravake  vaishnavi.boravake@abmspcoerpune.org
# 4          5     Rahul Chalavade     rahul.chalavade@abmspcoerpune.org
# ..       ...                 ...                                   ...
# 74        75      Sharwari Surve      sharwari.surve@abmspcoerpune.org
# 75        76  Suryakant Jambhale  suryakant.jambhale@abmspcoerpune.org
# 77        78      Rutweek Todkar      rutweek.todkar@abmspcoerpune.org
# 78        79       Jayshri Totre       jayshri.totre@abmspcoerpune.org
# 80        81        Akash Zagade        akash.zagade@abmspcoerpune.org
#
#     Password                                   Licenses
# 0   Fot79292  Microsoft 365 A3 for students use benefit
# ...

# %%
k12.dropna(inplace=True)
k12
# Out:
#           ID        Display name                              Username  \
# 0          1          Aakif Khan          aakif.khan@abmspcoerpune.org
# 1          2      Amarsinh Tarte      amarsinh.tarte@abmspcoerpune.org
# 2   not data      Vikram Bhosale      vikram.bhosale@abmspcoerpune.org
# 3          4  Vaishnavi Boravake  vaishnavi.boravake@abmspcoerpune.org
# 4          5     Rahul Chalavade     rahul.chalavade@abmspcoerpune.org
# ..       ...                 ...                                   ...
# 74        75      Sharwari Surve      sharwari.surve@abmspcoerpune.org
# 75        76  Suryakant Jambhale  suryakant.jambhale@abmspcoerpune.org
# 77        78      Rutweek Todkar      rutweek.todkar@abmspcoerpune.org
# 78        79       Jayshri Totre       jayshri.totre@abmspcoerpune.org
# 80        81        Akash Zagade        akash.zagade@abmspcoerpune.org
#
#     Password                                   Licenses
# 0   Fot79292  Microsoft 365 A3 for students use benefit
# ...

# %%
a=pd.read_csv('F:\\suryakant notes\\pra1.csv')
a
# Out:
#    ID       Name    Companies      Profit Growth
# 0    1   Lamtone  IT services   5274553.0    30%
# 1    2  Strifind      Finance         NaN    20%
# 2    3       NaN       Health  47689453.0     7%
# 3    4       NaN  IT services  23562549.0    NaN
# 4    5      Mark   Insurances   4563782.0    26%

# %%
a.fillna(10)
# Out:
#    ID       Name    Companies      Profit Growth
# 0    1   Lamtone  IT services   5274553.0    30%
# 1    2  Strifind      Finance        10.0    20%
# 2    3        10       Health  47689453.0     7%
# 3    4        10  IT services  23562549.0     10
# 4    5      Mark   Insurances   4563782.0    26%

# %%
a.fillna({'Name':'Shamy','Growth':'25%'})
# Out:
#    ID       Name    Companies      Profit Growth
# 0    1   Lamtone  IT services   5274553.0    30%
# 1    2  Strifind      Finance         NaN    20%
# 2    3     Shamy       Health  47689453.0     7%
# 3    4     Shamy  IT services  23562549.0    25%
# 4    5      Mark   Insurances   4563782.0    26%

# %%
a.fillna(method='bfill')
# Out:
#    ID       Name    Companies      Profit Growth
# 0    1   Lamtone  IT services   5274553.0    30%
# 1    2  Strifind      Finance  47689453.0    20%
# 2    3      Mark       Health  47689453.0     7%
# 3    4      Mark  IT services  23562549.0    26%
# 4    5      Mark   Insurances   4563782.0    26%

# %%
a.fillna(method='pad')
# Out:
#    ID       Name    Companies      Profit Growth
# 0    1   Lamtone  IT services   5274553.0    30%
# 1    2  Strifind      Finance   5274553.0    20%
# 2    3  Strifind       Health  47689453.0     7%
# 3    4  Strifind  IT services  23562549.0     7%
# 4    5      Mark   Insurances   4563782.0    26%

# %%
a.fillna(method='ffill',axis=0)
# Out:
#    ID       Name    Companies      Profit Growth
# 0    1   Lamtone  IT services   5274553.0    30%
# 1    2  Strifind      Finance   5274553.0    20%
# 2    3  Strifind       Health  47689453.0     7%
# 3    4  Strifind  IT services  23562549.0     7%
# 4    5      Mark   Insurances   4563782.0    26%

# %%
a.fillna(method='ffill',axis=1)
# Out:
#   ID       Name    Companies      Profit      Growth
# 0   1   Lamtone  IT services   5274553.0         30%
# 1   2  Strifind      Finance     Finance         20%
# 2   3         3       Health  47689453.0          7%
# 3   4         4  IT services  23562549.0  23562549.0
# 4   5      Mark   Insurances   4563782.0         26%

# %%
a.fillna(method='ffill',limit=1)
# Out:
#    ID       Name    Companies      Profit Growth
# 0    1   Lamtone  IT services   5274553.0    30%
# 1    2  Strifind      Finance   5274553.0    20%
# 2    3  Strifind       Health  47689453.0     7%
# 3    4       NaN  IT services  23562549.0     7%
# 4    5      Mark   Insurances   4563782.0    26%

# %%
a.fillna(100,limit=2)
# Out:
#    ID       Name    Companies      Profit Growth
# 0    1   Lamtone  IT services   5274553.0    30%
# 1    2  Strifind      Finance       100.0    20%
# 2    3       100       Health  47689453.0     7%
# 3    4       100  IT services  23562549.0    100
# 4    5      Mark   Insurances   4563782.0    26%

# %%
a.fillna(10,inplace=True)
a
# Out:
#    ID       Name    Companies      Profit Growth
# 0    1   Lamtone  IT services   5274553.0    30%
# 1    2  Strifind      Finance        10.0    20%
# 2    3        10       Health  47689453.0     7%
# 3    4        10  IT services  23562549.0     10
# 4    5      Mark   Insurances   4563782.0    26%

# %%
a
# Out:
#    ID       Name    Companies      Profit Growth
# 0    1   Lamtone  IT services   5274553.0    30%
# 1    2  Strifind      Finance        10.0    20%
# 2    3        10       Health  47689453.0     7%
# 3    4        10  IT services  23562549.0     10
# 4    5      Mark   Insurances   4563782.0    26%
